# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('/home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/')
from utils.unsupervised import Kmeans
from utils.evaluasi import elbow_method,hopkins_statistik,visual_silhoutte
from utils.EDA import visual_data

# %%
df = pd.read_csv('/home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/pre_processing/data_standard.csv')

# %%
x = df.to_numpy()

# %%
x
# Out:
# array([[ 1.28765971, -1.13486665,  0.2782514 , ..., -1.61423717,
#          1.89717646, -0.67714308],
#        [-0.53733286, -0.47822017, -0.09672528, ...,  0.6459238 ,
#         -0.85739418, -0.48416709],
#        [-0.27201464, -0.09882442, -0.96317624, ...,  0.66841296,
#         -0.03828924, -0.46398018],
#        ...,
#        [-0.37119902,  1.12691568,  0.00885068, ...,  0.28609718,
#         -0.65922363, -0.63584175],
#        [ 0.4470721 , -0.40525945, -0.59548067, ..., -0.34359941,
#          1.13752269, -0.63584175],
#        [ 1.11160744, -0.14989693, -0.3370016 , ..., -2.08650961,
#          1.61973769, -0.62765786]])

# %%
hopkins_statistik(x,2)
# Out:
# 0.5

# %%
visual_silhoutte(Kmeans,2,21,x)

# %%
elbow_method(Kmeans,2,21,x)

# %%
k = Kmeans(3,random_state=22)
k.fit_predict(x)
# Out:
# array([2, 0, 0, 2, 0, 0, 0, 1, 1, 0, 0, 1, 0, 0, 0, 1, 0, 2, 0, 0, 0, 0,
#        0, 1, 0, 2, 2, 0, 2, 1, 0, 2, 2, 0, 0, 0, 2, 2, 2, 0, 2, 0, 1, 1,
#        1, 0, 0, 0, 0, 2, 2, 0, 0, 1, 1, 2, 2, 0, 1, 2, 1, 0, 0, 2, 2, 0,
#        2, 0, 1, 0, 0, 0, 0, 1, 1, 1, 0, 1, 0, 0, 2, 2, 1, 0, 2, 0, 0, 2,
#        2, 0, 0, 1, 0, 2, 2, 0, 0, 2, 1, 2, 0, 0, 0, 0, 0, 0, 2, 0, 2, 0,
#        1, 1, 2, 2, 1, 0, 2, 0, 0, 0, 0, 0, 1, 1, 0, 0, 2, 0, 0, 2, 0, 0,
#        2, 1, 1, 1, 0, 2, 1, 1, 0, 0, 2, 0, 1, 1, 0, 2, 0, 2, 2, 0, 0, 0,
#        0, 2, 0, 1, 1, 1, 0, 0, 0, 0, 0, 2, 2])

# %%
visual_data("Kmeans",x,k.label__,2)
# Out:
#          PCA1      PCA2  label
# 0   -2.904290  0.095334      2
# 1    0.428622 -0.586392      0
# 2   -0.284370 -0.453810      0
# 3   -2.923630  1.690471      2
# 4    1.030477  0.136249      0
# ..        ...       ...    ...
# 162 -0.818170  0.637652      0
# 163 -0.549383 -1.230186      0
# 164  0.497030  1.386574      0
# 165 -1.881792 -0.109125      2
# 166 -2.855476  0.484541      2
#
# [167 rows x 3 columns]

# %% [markdown]
# #USING LIBRARY

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %%
range_n_clusters = range(1, 21)

# Inisialisasi list untuk menyimpan nilai inersia
inertia_values = []

# Coba beberapa jumlah klaster
for n_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(x)
    inertia_values.append(kmeans.inertia_)

# Plotting metode siku
plt.plot(range_n_clusters, inertia_values, marker='o')
plt.xlabel('Jumlah Klaster')
plt.ylabel('Inersia (Within-Cluster Sum of Squares)')
plt.title('Metode Siku untuk Menentukan Jumlah Klaster Optimal')
plt.show()
# Out:
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
range_n_clusters = range(2, 21)

# Inisialisasi list untuk menyimpan Silhouette Scores
silhouette_scores = []

# Coba beberapa jumlah klaster
for n_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(x)
    labels = kmeans.labels_
    silhouette_avg = silhouette_score(x, labels)
    silhouette_scores.append(silhouette_avg)

# Plotting Silhouette Scores
plt.plot(range_n_clusters, silhouette_scores, marker='o')
plt.xlabel('Jumlah Klaster')
plt.ylabel('Silhouette Score')
plt.title('Grafik Silhouette Score untuk Evaluasi Klastering')
plt.show()
# Out:
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
c = KMeans(3)
c.fit_predict(x)
# Out:
# /home/khalifardy/Dokumen/ruang_kerja/code/kuliah/ML/klasterisasi_negara/.env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# array([1, 2, 2, 1, 2, 2, 2, 0, 0, 2, 2, 0, 2, 2, 2, 0, 2, 1, 2, 2, 2, 1,
#        2, 0, 2, 1, 1, 2, 1, 0, 2, 1, 1, 2, 2, 2, 1, 1, 1, 2, 1, 2, 0, 0,
#        0, 2, 2, 2, 2, 1, 1, 2, 2, 0, 0, 1, 1, 2, 0, 1, 0, 2, 2, 1, 1, 2,
#        1, 2, 0, 2, 2, 2, 1, 0, 0, 0, 2, 0, 2, 2, 1, 1, 0, 2, 1, 2, 2, 1,
#        1, 2, 2, 0, 2, 1, 1, 2, 2, 1, 0, 1, 2, 2, 2, 2, 2, 2, 1, 2, 1, 2,
#        0, 0, 1, 1, 0, 2, 1, 2, 2, 2, 2, 2, 0, 0, 2, 2, 1, 2, 2, 1, 2, 2,
#        1, 0, 0, 0, 2, 1, 0, 0, 2, 2, 1, 2, 0, 0, 2, 1, 2, 1, 1, 2, 2, 2,
#        2, 1, 2, 0, 0, 0, 2, 2, 2, 2, 2, 1, 1], dtype=int32)

# %%
visual_data("Kmeans",x,c.labels_)
# Out:
#          PCA1      PCA2  label
# 0   -2.904290  0.095334      1
# 1    0.428622 -0.586392      2
# 2   -0.284370 -0.453810      2
# 3   -2.923630  1.690471      1
# 4    1.030477  0.136249      2
# ..        ...       ...    ...
# 162 -0.818170  0.637652      2
# 163 -0.549383 -1.230186      2
# 164  0.497030  1.386574      2
# 165 -1.881792 -0.109125      1
# 166 -2.855476  0.484541      1
#
# [167 rows x 3 columns]
